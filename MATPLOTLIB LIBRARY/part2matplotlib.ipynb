# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#importing library
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname=r'abc.jpg'

#opening image using pil

Image=Image.open(fname).convert('L')

#convering to gray scale
plt.imshow(Image,cmap='gray')

# %%
#importing library
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname=r'abc.jpg'

#opening image using pil

Image=Image.open(fname).convert('L')

#convering to gray scale
plt.imshow(Image)

# %%
#importing library
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname=r'bird.jpg'

#opening image using pil

Image=Image.open(fname).convert('L')

#convering to gray scale
plt.imshow(Image,cmap='gray')
plt.show()

# %%
#importing library
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname=r'bird.jpg'

#opening image using pil

Image=Image.open(fname).convert('L')

#convering to gray scale
plt.imshow(Image,cmap='Pastel1') #cmap have no as 'g 'color it  show error
plt.show()

# %% [markdown]
# MATPLOTLIB -PIE

# %%
import matplotlib.pyplot as plt

# %%
x=[10,20,30,40]
y=['math','hindi','science','enlish']
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0xb3e97c0>,
# ...
#  [Text(1.0461621649530053, 0.3399187029582827, 'math'),
#   Text(0.33991865722907993, 1.0461621798113232, 'hindi'),
#   Text(-1.046162235191088, 0.33991848678762215, 'science'),
#   Text(0.33991884014588697, -1.0461621203780394, 'enlish')])

# %%
x=[10,20,30,40]
y=['math','hindi','science','enlish']
plt.pie(x,labels=y)
plt.show()
